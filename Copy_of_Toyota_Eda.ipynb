# %% [markdown]
# <a href="https://colab.research.google.com/github/Koush98/Koush98/blob/main/Copy_of_Toyota_Eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-colab
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.3 MB/s eta 0:00:00
# ...

# %%
import google.colab

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df=pd.read_csv('/content/drive/MyDrive/data_sets/Toyota (1).csv', index_col=0)

# %%
df
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986   Diesel   90       1.0          0  2000  three
# 1     13750  23.0  72937   Diesel   90       1.0          0  2000      3
# 2     13950  24.0  41711   Diesel   90       NaN          0  2000      3
# 3     14950  26.0  48000   Diesel   90       0.0          0  2000      3
# 4     13750  30.0  38500   Diesel   90       0.0          0  2000      3
# ...     ...   ...    ...      ...  ...       ...        ...   ...    ...
# 1431   7500   NaN  20544   Petrol   86       1.0          0  1300      3
# 1432  10845  72.0     ??   Petrol   86       0.0          0  1300      3
# 1433   8500   NaN  17016   Petrol   86       0.0          0  1300      3
# 1434   7250  70.0     ??      NaN   86       1.0          0  1300      3
# 1435   6950  76.0      1   Petrol  110       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1436 non-null   object
#  3   FuelType   1336 non-null   object
#  4   HP         1436 non-null   object
#  5   MetColor   1286 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 123.4+ KB

# %%
df.columns
# Out:
# Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Price          Age     MetColor    Automatic           CC  \
# count   1436.000000  1336.000000  1286.000000  1436.000000  1436.000000
# mean   10730.824513    55.672156     0.674961     0.055710  1566.827994
# std     3626.964585    18.589804     0.468572     0.229441   187.182436
# min     4350.000000     1.000000     0.000000     0.000000  1300.000000
# 25%     8450.000000    43.000000     0.000000     0.000000  1400.000000
# 50%     9900.000000    60.000000     1.000000     0.000000  1600.000000
# 75%    11950.000000    70.000000     1.000000     0.000000  1600.000000
# max    32500.000000    80.000000     1.000000     1.000000  2000.000000
#
#            Weight
# count  1436.00000
# mean   1072.45961
# std      52.64112
# min    1000.00000
# 25%    1040.00000
# 50%    1070.00000
# 75%    1085.00000
# max    1615.00000

# %%
df2=df.copy(deep=True)

# %%
df2
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986   Diesel   90       1.0          0  2000  three
# 1     13750  23.0  72937   Diesel   90       1.0          0  2000      3
# 2     13950  24.0  41711   Diesel   90       NaN          0  2000      3
# 3     14950  26.0  48000   Diesel   90       0.0          0  2000      3
# 4     13750  30.0  38500   Diesel   90       0.0          0  2000      3
# ...     ...   ...    ...      ...  ...       ...        ...   ...    ...
# 1431   7500   NaN  20544   Petrol   86       1.0          0  1300      3
# 1432  10845  72.0     ??   Petrol   86       0.0          0  1300      3
# 1433   8500   NaN  17016   Petrol   86       0.0          0  1300      3
# 1434   7250  70.0     ??      NaN   86       1.0          0  1300      3
# 1435   6950  76.0      1   Petrol  110       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...

# %%
df2.isnull().sum()
# Out:
# Price          0
# Age          100
# KM             0
# FuelType     100
# HP             0
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
df2["Age"].fillna(df["Age"].mean(), inplace=True)

# %%
df2.isnull().sum()
# Out:
# Price          0
# Age          100
# KM             0
# FuelType     100
# HP             0
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
df2["FuelType"].fillna(df2["FuelType"].mode()[0], inplace=True)

# %%
df2.isnull().sum()
# Out:
# Price          0
# Age            0
# KM             0
# FuelType       0
# HP             0
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
df2["MetColor"].fillna(df2["MetColor"].mode()[0], inplace=True)

# %%
df2.isnull().sum()
# Out:
# Price        0
# Age          0
# KM           0
# FuelType     0
# HP           0
# MetColor     0
# Automatic    0
# CC           0
# Doors        0
# Weight       0
# dtype: int64

# %%
df2['Age'] = df2['Age'].astype(int)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   int64
#  2   KM         1436 non-null   object
#  3   FuelType   1436 non-null   object
#  4   HP         1436 non-null   object
#  5   MetColor   1436 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 123.4+ KB

# %%
df2["KM"].replace("??", np.nan)
# Out:
# 0       46986
# 1       72937
# 2       41711
# 3       48000
# 4       38500
#         ...
# 1431    20544
# 1432      NaN
# 1433    17016
# 1434      NaN
# 1435        1
# Name: KM, Length: 1436, dtype: object

# %%
df2["KM"].value_counts()
# Out:
# KM
# ??       15
# 1         8
# 59000     7
# 36000     7
# 43000     7
#          ..
# 63635     1
# 63792     1
# 64193     1
# 65170     1
# 17016     1
# Name: count, Length: 1256, dtype: int64

# %%
df2["KM"].replace("??", np.nan, inplace=True)

# %%
df2["KM"].value_counts()
# Out:
# KM
# 1        8
# 59000    7
# 36000    7
# 43000    7
# 10000    6
#         ..
# 63635    1
# 63792    1
# 64193    1
# 65170    1
# 17016    1
# Name: count, Length: 1255, dtype: int64

# %%
df2["KM"].astype(float)
# Out:
# 0       46986.0
# 1       72937.0
# 2       41711.0
# 3       48000.0
# 4       38500.0
#          ...
# 1431    20544.0
# 1432        NaN
# 1433    17016.0
# 1434        NaN
# 1435        1.0
# Name: KM, Length: 1436, dtype: float64

# %%
df2["KM"] = df2["KM"].astype(float)

# %%
df2["KM"].fillna(df2["KM"].mean(), inplace=True)

# %%
df2. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   int64
#  2   KM         1436 non-null   float64
#  3   FuelType   1436 non-null   object
#  4   HP         1436 non-null   object
#  5   MetColor   1436 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 123.4+ KB

# %%
df2["KM"].value_counts()
# Out:
# KM
# 68647.239972    15
# 1.000000         8
# 59000.000000     7
# 36000.000000     7
# 43000.000000     7
#                 ..
# 63635.000000     1
# 63792.000000     1
# 64193.000000     1
# 65170.000000     1
# 17016.000000     1
# Name: count, Length: 1256, dtype: int64

# %%
df2
# Out:
#       Price  Age            KM FuelType   HP  MetColor  Automatic    CC  \
# 0     13500   23  46986.000000   Diesel   90       1.0          0  2000
# 1     13750   23  72937.000000   Diesel   90       1.0          0  2000
# 2     13950   24  41711.000000   Diesel   90       1.0          0  2000
# 3     14950   26  48000.000000   Diesel   90       0.0          0  2000
# 4     13750   30  38500.000000   Diesel   90       0.0          0  2000
# ...     ...  ...           ...      ...  ...       ...        ...   ...
# 1431   7500   55  20544.000000   Petrol   86       1.0          0  1300
# 1432  10845   72  68647.239972   Petrol   86       0.0          0  1300
# 1433   8500   55  17016.000000   Petrol   86       0.0          0  1300
# 1434   7250   70  68647.239972   Petrol   86       1.0          0  1300
# 1435   6950   76      1.000000   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# 0     three    1165
# 1         3    1165
# 2         3    1165
# ...

# %%
Price=df["Price"]

# %%
df1_sorted = df2.sort_values(by='Doors')
df1_sorted

# Sort DataFrame by the 'Doors' column in descending order
# Out:
#       Price  Age        KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 761    8250   65   80000.0   Petrol   86       1.0          0  1300      2
# 1078   7950   71  139145.0   Diesel   73       0.0          0  2000      2
# 717    9750   64   89145.0   Petrol   86       1.0          0  1300      3
# 431   10950   50   82735.0   Petrol   97       1.0          0  1400      3
# 433   11290   49   80320.0   Petrol  110       1.0          1  1600      3
# ...     ...  ...       ...      ...  ...       ...        ...   ...    ...
# 576   11500   46   34000.0   Petrol  110       1.0          0  1600      5
# 553   10995   55   41273.0   Petrol   97       0.0          0  1400      5
# 324   12950   39   34599.0   Petrol  110       1.0          0  1600   five
# 167   20950   14    5278.0   Petrol  110       1.0          1  1600   four
# 0     13500   23   46986.0   Diesel   90       1.0          0  2000  three
#
#       Weight
# 761     1015
# 1078    1115
# 717     1025
# ...

# %%
df2.head()
# Out:
#    Price  Age       KM FuelType  HP  MetColor  Automatic    CC  Doors  Weight
# 0  13500   23  46986.0   Diesel  90       1.0          0  2000  three    1165
# 1  13750   23  72937.0   Diesel  90       1.0          0  2000      3    1165
# 2  13950   24  41711.0   Diesel  90       1.0          0  2000      3    1165
# 3  14950   26  48000.0   Diesel  90       0.0          0  2000      3    1165
# 4  13750   30  38500.0   Diesel  90       0.0          0  2000      3    1170

# %%
sns.scatterplot(y="Price", x="Age", data=df2,hue="FuelType")
plt.title("Price Vs Age")
plt.xlabel("Age")
plt.ylabel("Price")
plt.show()

# %%
sns.jointplot(y="Price", x="Age", data=df2,kind="reg")
plt.title("Price Vs Age")
plt.xlabel("Age")
plt.ylabel("Price")
plt.show()

# %%
sns.scatterplot(y="Price", x="KM", data=df2,hue="FuelType")
plt.title("Price Vs KM")
plt.xlabel("KM")
plt.ylabel("Price")
plt.show()

# %%
sns.scatterplot(y="Price", x="HP", data=df2,hue="FuelType")
plt.title("Price Vs HP")
plt.xlabel("HP")
plt.ylabel("Price")
plt.show()

# %%
df2["HP"].value_counts()
# Out:
# HP
# 107    510
# 97     421
# 72     321
# 90      71
# 69      63
# 192     28
# 116     12
# 98       5
# 71       3
# 73       2
# Name: count, dtype: int64

# %%
df2["HP"].replace("????",df2["HP"].mode()[0],inplace=True)

# %%
sns.scatterplot(y="Price", x="HP", data=df2,hue="FuelType")
plt.title("Price Vs HP")
plt.xlabel("HP")
plt.ylabel("Price")
plt.show()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   int64
#  2   KM         1436 non-null   float64
#  3   FuelType   1436 non-null   object
#  4   HP         1436 non-null   object
#  5   MetColor   1436 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 155.7+ KB

# %%
sns.scatterplot(y="Price", x="CC", data=df2,hue="FuelType")
plt.title("Price Vs CC")
plt.xlabel("CC")
plt.ylabel("Price")
plt.show()

# %%
sns.jointplot(y="Price", x="Weight", data=df2,kind="reg")
plt.title("Price Vs HP")
plt.xlabel("HP")
plt.ylabel("Price")
plt.show()

# %%
sns.jointplot(y="KM", x="Age", data=df2,kind="reg")
plt.title("KM Vs Age")
plt.xlabel("Age")
plt.ylabel("KM")
plt.show()

# %%
sns.boxplot(df2["HP"])
# Out:
# <Axes: ylabel='HP'>

# %%
df2["HP"].astype(float)
# Out:
# 0        90.0
# 1        90.0
# 2        90.0
# 3        90.0
# 4        90.0
#         ...
# 1431    107.0
# 1432    107.0
# 1433    107.0
# 1434    107.0
# 1435    107.0
# Name: HP, Length: 1436, dtype: float64

# %%
df2["HP"].unique()
# Out:
# array(['90', '107', '192', '97', '71', '116', '98', '69', '72', '73'],
#       dtype=object)

# %%
p=df2["HP"].unique()

# %%
plt.pie(p, labels=p, autopct='%1.1f%%')
plt.title("Pie Chart of HP")
plt.legend(p)
plt.show()

# %%
df2.columns
# Out:
# Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')

# %%
sns.barplot(x="FuelType",y="Price", data=df2, hue="MetColor")
plt.show()

# %%
sns.barplot(x="MetColor",y="Price", data=df2, hue="FuelType")
plt.show()

# %%
sns.barplot(x="FuelType",y="Price", data=df2, hue="Doors")
plt.show()

# %%
sns.barplot(x="MetColor",y="Price", data=df2, hue="Doors")
plt.show()

# %%
sns.distplot(df2["Price"],color="purple")
plt.show()
# Out:
# <ipython-input-52-7e1fb2ff2ca6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2["Price"],color="purple")

# %%
sns.distplot(df2["Price"],hist=False)
plt.show()
# Out:
# <ipython-input-51-b7d39432fb89>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2["Price"],hist=False)

# %%
sns.distplot(df2["Price"],kde=False,bins=50, color="Green")
plt.show()
# Out:
# <ipython-input-58-be2964da45f8>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2["Price"],kde=False,bins=50, color="Green")

# %%
sns.boxplot(x="FuelType",y="Price", data=df2,palette="Set3")
plt.show()
# Out:
# <ipython-input-75-bff5ace61f4d>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="FuelType",y="Price", data=df2,palette="Set3")

# %%
sns.boxplot(x="MetColor",y="Price", data=df2,palette="Set2")
plt.show()
# Out:
# <ipython-input-76-44f09aaba543>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="MetColor",y="Price", data=df2,palette="Set2")

# %%
df2.columns
# Out:
# Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')

# %%
sns.boxplot(x="Automatic",y="Price", data=df2,palette="Set1")
plt.show()
# Out:
# <ipython-input-73-77c5cedc4eea>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Automatic",y="Price", data=df2,palette="Set1")

# %%
sns.boxplot(x="FuelType",y="Price", data=df2,palette="Set1",hue="MetColor")
plt.show()

# %%
sns.boxplot(x="FuelType",y="Price", data=df2,palette="Set1",hue="Doors")
plt.show()

# %%
df2.replace({"three":3,"four":4,"five":5},inplace=True)

# %%
sns.boxplot(x="FuelType",y="Price", data=df2,palette="Set1",hue="Doors")
plt.show()

# %%
sns.pairplot(df2, hue="FuelType")
plt.show()

# %%
sns.pairplot(df2, hue="MetColor")
plt.show()

# %%
sns.pairplot(df2, hue="Doors")
plt.show()
